# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import scipy.cluster.hierarchy as sch
from scipy.cluster.hierarchy import linkage
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import silhouette_score

# %%
data=pd.read_csv('crime_data.csv')
data
# Out:
#               city  Murder  Assault  UrbanPop  Rape
# 0          Alabama    13.2      236        58  21.2
# 1           Alaska    10.0      263        48  44.5
# 2          Arizona     8.1      294        80  31.0
# 3         Arkansas     8.8      190        50  19.5
# 4       California     9.0      276        91  40.6
# 5         Colorado     7.9      204        78  38.7
# 6      Connecticut     3.3      110        77  11.1
# 7         Delaware     5.9      238        72  15.8
# 8          Florida    15.4      335        80  31.9
# 9          Georgia    17.4      211        60  25.8
# 10          Hawaii     5.3       46        83  20.2
# 11           Idaho     2.6      120        54  14.2
# 12        Illinois    10.4      249        83  24.0
# 13         Indiana     7.2      113        65  21.0
# 14            Iowa     2.2       56        57  11.3
# 15          Kansas     6.0      115        66  18.0
# 16        Kentucky     9.7      109        52  16.3
# ...

# %%
data1=data.drop(['city'],axis=1)
data1.head()
# Out:
#    Murder  Assault  UrbanPop  Rape
# 0    13.2      236        58  21.2
# 1    10.0      263        48  44.5
# 2     8.1      294        80  31.0
# 3     8.8      190        50  19.5
# 4     9.0      276        91  40.6

# %%
scale=MinMaxScaler()
data2=pd.DataFrame(scale.fit_transform(data1))
data2.head()
# Out:
#           0         1         2         3
# 0  0.746988  0.654110  0.440678  0.359173
# 1  0.554217  0.746575  0.271186  0.961240
# 2  0.439759  0.852740  0.813559  0.612403
# 3  0.481928  0.496575  0.305085  0.315245
# 4  0.493976  0.791096  1.000000  0.860465

# %%
link=linkage(data2,method="complete",metric="euclidean")
sch.dendrogram(link)
plt.show()

# %%
final=AgglomerativeClustering(n_clusters=4,linkage='complete',affinity="euclidean").fit(data2)
labels=pd.Series(final.labels_)
labels.head()
# Out:
# 0    0
# 1    0
# 2    3
# 3    1
# 4    3
# dtype: int64

# %%
data['clust']=labels
data
# Out:
#               city  Murder  Assault  UrbanPop  Rape  clust
# 0          Alabama    13.2      236        58  21.2      0
# 1           Alaska    10.0      263        48  44.5      0
# 2          Arizona     8.1      294        80  31.0      3
# 3         Arkansas     8.8      190        50  19.5      1
# 4       California     9.0      276        91  40.6      3
# 5         Colorado     7.9      204        78  38.7      3
# 6      Connecticut     3.3      110        77  11.1      1
# 7         Delaware     5.9      238        72  15.8      1
# 8          Florida    15.4      335        80  31.9      3
# 9          Georgia    17.4      211        60  25.8      0
# 10          Hawaii     5.3       46        83  20.2      1
# 11           Idaho     2.6      120        54  14.2      2
# 12        Illinois    10.4      249        83  24.0      3
# 13         Indiana     7.2      113        65  21.0      1
# 14            Iowa     2.2       56        57  11.3      2
# ...

# %%
data1.iloc[:,0:].groupby(data.clust).mean()
# Out:
#           Murder     Assault   UrbanPop     Rape
# clust
# 0      14.087500  252.750000  53.500000  24.5375
# 1       5.715000  132.300000  70.800000  18.1000
# 2       3.180000   78.700000  49.300000  11.6300
# 3      10.883333  256.916667  78.333333  32.2500

# %%
data1.plot(x="Murder",y ="Assault",c=labels,kind="scatter",s=50 ,cmap=plt.cm.copper_r) 
plt.title('Clusters using h')
# Out:
# Text(0.5, 1.0, 'Clusters using h')
